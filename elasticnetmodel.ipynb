# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
data_2022= pd.read_csv('C:/Users/sivar/capstoneB/data/processed_22.csv')
data_2023 = pd.read_csv('C:/Users/sivar/capstoneB/data/processed_23.csv')
data_2024 = pd.read_csv('C:/Users/sivar/capstoneB/data/processed_24.csv')
data_2025 = pd.read_csv('C:/Users/sivar/capstoneB/data/processed_25.csv')

# %%
data_2022.head(25)
# change date to months for summer months and winter
# Out:
#         date     roiCount  ml_analyzed  ROI_per_ml  Lpoly_expected  \
# 0   20221005   213.288889     4.893459   43.686985       22.935411
# 1   20221006   162.452830     4.894287   33.366936       13.319224
# 2   20221007   169.980000     4.872823   34.833416        5.074974
# 3   20221008   336.345455     4.859085   69.553816        9.665164
# 4   20221009   561.684211     4.786618  118.117103       47.861245
# 5   20221010   671.339286     4.764006  142.216029       26.403383
# 6   20221011   601.100000     4.787495  127.216492       18.992023
# 7   20221013   489.500000     4.827143  101.419554        5.156239
# 8   20221014  1472.603774     4.500468  341.099674        1.056346
# 9   20221019   474.000000     4.839772   98.228363        0.025648
# 10  20221020   557.603448     4.798546  117.054306        0.583053
# 11  20221021   345.542857     4.869174   71.229382        1.478075
# 12  20221022   222.862069     4.896622   45.736892        0.690282
# ...

# %%
y_data_train = data_2022['Lpoly_expected_ml']
x_data_train = data_2022.drop(columns=["date", "Lpoly_expected", "Lpoly_expected_ml","Pmicans_expected","Pmicans_expected_ml"],axis=1)

# %%
model = ElasticNet(alpha = 0.1, l1_ratio = 0.5)

# %%
predictions = model.fit(x_data, y_data)
y_pred = model.predict(x_data)
mse = mean_squared_error(y_data, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 1.5570067126969414
# c:\Users\sivar\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.286e+01, tolerance: 2.509e-02
#   model = cd_fast.enet_coordinate_descent(

# %%
y_pred
# Out:
# array([ 2.32860627e+00,  1.53879338e+00,  2.23729256e+00,  3.67484111e+00,
#         5.05959575e+00,  5.55388105e+00,  4.43799741e+00,  3.34465111e+00,
#         1.07664732e+00,  1.62510303e-01,  9.15203798e-01,  3.05024788e-01,
#         5.29119054e-01, -6.57920222e-03, -3.31088027e-01, -5.34033407e-01,
#         3.03434633e-02,  5.02312420e-01,  1.00944462e+00,  3.40445179e+00,
#         3.31485398e+00,  2.39965909e+00,  2.98231648e+00,  6.85201008e+00,
#         4.86377640e+00,  2.82473665e+00,  9.00915020e-01,  4.70276047e-01,
#         3.68204341e+00,  2.91591342e+00,  1.89548632e+00,  1.54407098e+00,
#         9.02427086e-01,  6.17042088e-01,  1.09936377e+00, -3.59314451e-01,
#        -3.54077407e-01, -4.74082263e-01,  1.26900830e+00, -1.94191275e-01,
#        -4.36316160e-02,  5.14425005e-02,  1.63325229e+00,  9.58450733e-01,
#        -4.14693083e-01,  8.00912431e-01, -7.59262404e-01,  5.63819546e-01,
#         1.28159661e+00])

# %%
elasticnet_coeff = model.coef_
feature_coeff_df = pd.DataFrame({'Feature': x_data.columns, 'Coefficient': elasticnet_coeff})
feature_coeff_df.drop(feature_coeff_df[feature_coeff_df['Coefficient'] == 0].index, inplace=True)
feature_coeff_df.head(20)
# Out:
#                       Feature   Coefficient
# 0                    roiCount  7.132275e-02
# 2                  ROI_per_ml -3.007618e-01
# 3                        Area -1.621497e-03
# 7                   Biovolume -9.309339e-06
# 8          BoundingBox_xwidth  1.677739e-01
# 9          BoundingBox_ywidth  1.275436e-01
# 10                 ConvexArea -5.221435e-04
# 11            ConvexPerimeter  1.059803e-02
# 19            MinorAxisLength  5.503539e-03
# 20                Orientation -3.272773e-02
# 21                  Perimeter -4.927507e-02
# 23        RWhalfpowerintegral  8.469906e-07
# 24        RepresentativeWidth -1.270136e-01
# 25  RotatedBoundingBox_xwidth  1.992675e-01
# 26  RotatedBoundingBox_ywidth -1.002023e-01
# 28                SurfaceArea  2.206747e-04
# 35          moment_invariant5  4.226892e-03
# 37          moment_invariant7  3.528325e-03
# 43                 summedArea -1.741911e-03
# 44            summedBiovolume -9.731491e-06

# %%
y_data.describe()
# Out:
# count    49.000000
# mean      1.560472
# std       2.286280
# min       0.005313
# 25%       0.229782
# 50%       0.498683
# 75%       1.959072
# max      10.082290
# Name: Lpoly_expected_ml, dtype: float64

# %%
y_data_val.describe()
# Out:
# count    185.000000
# mean       2.916031
# std        5.859977
# min        0.000216
# 25%        0.056835
# 50%        0.580106
# 75%        2.565429
# max       37.742277
# Name: Lpoly_expected_ml, dtype: float64

# %%
y_data_val_2023 = data_2023['Lpoly_expected_ml']
x_data_val_2023 = data_2023.drop(columns=["date", "Lpoly_expected", "Lpoly_expected_ml"],axis=1)
y_pred_2023 = model.predict(x_data_val_2023)
df_describe = pd.DataFrame(y_pred_2023)
df_describe.describe()
# Out:
#                 0
# count  185.000000
# mean     2.600778
# std     10.423688
# min    -31.914442
# 25%      0.311566
# 50%      1.765361
# 75%      3.431208
# max    106.502708

# %%
mse_2023 = mean_squared_error(y_data_val_2023, y_pred_2023)
mse_2023
# Out:
# 132.01317278202364

# %%
y_data_val_2024 = data_2024['Lpoly_expected_ml']
x_data_val_2024 = data_2024.drop(columns=["date", "Lpoly_expected", "Lpoly_expected_ml"],axis=1)
y_pred_2024 = model.predict(x_data_val_2024)
pd.DataFrame(y_pred_2024)
# Out:
#             0
# 0    5.050019
# 1    5.083641
# 2   -0.789822
# 3    2.403191
# 4    6.034118
# ..        ...
# 279  3.783683
# 280  4.042326
# 281  2.395213
# 282  5.708366
# 283  5.387011
#
# [284 rows x 1 columns]

# %%
mse_2024 = mean_squared_error(y_data_val_2024, y_pred_2024)
mse_2024
# Out:
# 21396113.51978889

# %%
# Out:
# c:\Users\sivar\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.762e+01, tolerance: 2.509e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\sivar\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.582e+01, tolerance: 2.509e-02
#   model = cd_fast.enet_coordinate_descent(
# alpha=   1 | 2023 MSE:        37.02 | 2024 MSE:    565547.39
# alpha=  10 | 2023 MSE:        35.74 | 2024 MSE:      1094.68
# alpha=  50 | 2023 MSE:        36.07 | 2024 MSE:       427.51
# alpha= 100 | 2023 MSE:        36.23 | 2024 MSE:       238.25
# ...

# %%
reguralized_coeff = model2.coef_
reguralized_feature_coeff_df = pd.DataFrame({'Feature': x_data_train.columns, 'Coefficient': reguralized_coeff})
reguralized_feature_coeff_df.drop(reguralized_feature_coeff_df[reguralized_feature_coeff_df['Coefficient'] == 0].index, inplace=True)
reguralized_feature_coeff_df.head(20)
# Out:
#                 Feature   Coefficient
# 0              roiCount  1.851148e-03
# 3                  Area  8.627582e-04
# 7             Biovolume -1.686189e-05
# 23  RWhalfpowerintegral  1.910719e-07
# 28          SurfaceArea  2.815509e-04
# 44      summedBiovolume -1.911457e-05
# 50    summedSurfaceArea  2.430158e-04

# %%
total["date"] = pd.to_datetime(total["date"])
y = total['Lpoly_expected_ml']
X = total.drop(columns=["date", "Lpoly_expected", "Lpoly_expected_ml","Pmicans_expected","Pmicans_expected_ml"])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=23)

# %%
elanetmod = Pipeline([
    ('scaler', RobustScaler()),
    ('model',  ElasticNet(alpha=1, l1_ratio=0.5, max_iter=10000)),
    
])
elanetmod.fit(X_train, y_train)
y_pred = elanetmod.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")
print(f"R^2 Score: {r2:.2f}")

# %%
model_name = elanetmod.named_steps['model']
model_name_coeff = model_name.coef_
feature_coeff_df = pd.DataFrame({'Feature': X_train.columns, 'Coefficient': abs(model_name_coeff)})
feature_coeff_df.drop(feature_coeff_df[feature_coeff_df['Coefficient'] == 0].index, inplace=True)
feature_coeff_df.head(20).sort_values(by='Coefficient', ascending=True)
